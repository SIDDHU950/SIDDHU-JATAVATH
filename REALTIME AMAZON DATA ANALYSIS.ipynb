# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as asns

# %%
df=  pd.read_csv(r"C:\Users\jatav\Downloads\amazon_products_sales_data_cleaned.csv")

# %%
df.head
# Out:
# <bound method NDFrame.head of                                            product_title  product_rating  \
# 0      BOYA BOYALINK 2 Wireless Lavalier Microphone f...             4.6
# 1      LISEN USB C to Lightning Cable, 240W 4 in 1 Ch...             4.3
# 2      DJI Mic 2 (2 TX + 1 RX + Charging Case), Wirel...             4.6
# 3      Apple AirPods Pro 2 Wireless Earbuds, Active N...             4.6
# 4      Apple AirTag 4 Pack. Keep Track of and find Yo...             4.8
# ...                                                  ...             ...
# 42670  Elgato 4K Pro, Internal Capture Card: 8K60 Pas...             5.0
# 42671  Arlo Essential Spotlight Camera, Wireless Secu...             4.2
# 42672  GIGABYTE - AORUS FO32U2-32" QD OLED Gaming Mon...             4.3
# 42673  Monoprice XLR Male to 1/4-Inch TRS Male Cable ...             4.7
# 42674  Lorex Fusion 1080p HD Security Camera System w...             4.4
#
# ...

# %%
df.head(2)
# Out:
#                                        product_title  product_rating  \
# 0  BOYA BOYALINK 2 Wireless Lavalier Microphone f...             4.6
# 1  LISEN USB C to Lightning Cable, 240W 4 in 1 Ch...             4.3
#
#    total_reviews  purchased_last_month  discounted_price  original_price  \
# 0          375.0                 300.0             89.68          159.00
# 1         2457.0                6000.0              9.99           15.99
#
#   is_best_seller is_sponsored             has_coupon buy_box_availability  \
# 0       No Badge    Sponsored  Save 15%  with coupon          Add to cart
# 1       No Badge    Sponsored              No Coupon          Add to cart
#
#   delivery_date sustainability_tags  \
# 0    2025-09-01       Carbon impact
# 1    2025-08-29                 NaN
#
#                                    product_image_url  \
# 0  https://m.media-amazon.com/images/I/71pAqiVEs3...
# 1  https://m.media-amazon.com/images/I/61nbF6aVIP...
#
# ...

# %%
df.info
# Out:
# <bound method DataFrame.info of                                            product_title  product_rating  \
# 0      BOYA BOYALINK 2 Wireless Lavalier Microphone f...             4.6
# 1      LISEN USB C to Lightning Cable, 240W 4 in 1 Ch...             4.3
# 2      DJI Mic 2 (2 TX + 1 RX + Charging Case), Wirel...             4.6
# 3      Apple AirPods Pro 2 Wireless Earbuds, Active N...             4.6
# 4      Apple AirTag 4 Pack. Keep Track of and find Yo...             4.8
# ...                                                  ...             ...
# 42670  Elgato 4K Pro, Internal Capture Card: 8K60 Pas...             5.0
# 42671  Arlo Essential Spotlight Camera, Wireless Secu...             4.2
# 42672  GIGABYTE - AORUS FO32U2-32" QD OLED Gaming Mon...             4.3
# 42673  Monoprice XLR Male to 1/4-Inch TRS Male Cable ...             4.7
# 42674  Lorex Fusion 1080p HD Security Camera System w...             4.4
#
# ...

# %%
len(df)
# Out:
# 42675

# %%
df.isnull().sum()
# Out:
# product_title               0
# product_rating           1024
# total_reviews            1024
# purchased_last_month    10511
# discounted_price         2062
# original_price           2062
# is_best_seller              0
# is_sponsored                0
# has_coupon                  0
# buy_box_availability    14653
# delivery_date           11983
# sustainability_tags     39267
# product_image_url           0
# product_page_url         2069
# data_collected_at           0
# product_category            0
# discount_percentage      2062
# dtype: int64

# %%
df.isnull().sum()*100/len(df)
# Out:
# product_title            0.000000
# product_rating           2.399531
# total_reviews            2.399531
# purchased_last_month    24.630346
# discounted_price         4.831869
# original_price           4.831869
# is_best_seller           0.000000
# is_sponsored             0.000000
# has_coupon               0.000000
# buy_box_availability    34.336262
# delivery_date           28.079672
# sustainability_tags     92.014060
# product_image_url        0.000000
# product_page_url         4.848272
# data_collected_at        0.000000
# product_category         0.000000
# discount_percentage      4.831869
# dtype: float64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.columns
# Out:
# Index(['product_title', 'product_rating', 'total_reviews',
#        'purchased_last_month', 'discounted_price', 'original_price',
#        'is_best_seller', 'is_sponsored', 'has_coupon', 'buy_box_availability',
#        'delivery_date', 'sustainability_tags', 'product_image_url',
#        'product_page_url', 'data_collected_at', 'product_category',
#        'discount_percentage'],
#       dtype='str')

# %%
df.describe().T
# Out:
#                         count         mean           std    min     25%  \
# product_rating        41651.0     4.399431      0.386997   1.00    4.20
# total_reviews         41651.0  3087.106000  13030.460133   1.00   82.00
# purchased_last_month  32164.0  1293.665278   6318.323574  50.00  100.00
# discounted_price      40613.0   243.227289    473.351545   2.16   29.69
# original_price        40613.0   257.611107    496.633495   2.16   32.99
# discount_percentage   40613.0     6.547151     12.744715   0.00    0.00
#
#                          50%      75%        max
# product_rating          4.50     4.70       5.00
# total_reviews         343.00  1886.00  865598.00
# purchased_last_month  200.00   400.00  100000.00
# discounted_price       84.99   224.00    5449.00
# original_price         89.00   229.99    5449.00
# discount_percentage     0.00     8.49      85.42

# %%
num_df=df.select_dtypes(include='number')
cat_df=df.select_dtypes(exclude='number')

# %%
cat_df
# Out:
#                                            product_title is_best_seller  \
# 0      BOYA BOYALINK 2 Wireless Lavalier Microphone f...       No Badge
# 1      LISEN USB C to Lightning Cable, 240W 4 in 1 Ch...       No Badge
# 2      DJI Mic 2 (2 TX + 1 RX + Charging Case), Wirel...       No Badge
# 3      Apple AirPods Pro 2 Wireless Earbuds, Active N...    Best Seller
# 4      Apple AirTag 4 Pack. Keep Track of and find Yo...       No Badge
# ...                                                  ...            ...
# 42670  Elgato 4K Pro, Internal Capture Card: 8K60 Pas...       No Badge
# 42671  Arlo Essential Spotlight Camera, Wireless Secu...       No Badge
# 42672  GIGABYTE - AORUS FO32U2-32" QD OLED Gaming Mon...       Save 18%
# 42673  Monoprice XLR Male to 1/4-Inch TRS Male Cable ...       No Badge
# 42674  Lorex Fusion 1080p HD Security Camera System w...       No Badge
#
#       is_sponsored                has_coupon buy_box_availability  \
# ...

# %%
num_df=df.select_dtypes(include='number')
cat_df=df.select_dtypes(exclude='number')

# %%
num_df.isna().sum()
# Out:
# product_rating           1024
# total_reviews            1024
# purchased_last_month    10511
# discounted_price         2062
# original_price           2062
# discount_percentage      2062
# dtype: int64

# %%
for column in num_df.columns:
 num_df[column]=num_df[column].fillna(num_df[column].median())

# %%
num_df.isnull().sum()
# Out:
# product_rating          0
# total_reviews           0
# purchased_last_month    0
# discounted_price        0
# original_price          0
# discount_percentage     0
# dtype: int64

# %%
cat_df['buy_box_availability'].mode().values[0]
# Out:
# 'Add to cart'

# %%
for column in cat_df:
    print(column)
    cat_df[column].mode().values[0]
# Out:
# product_title
# is_best_seller
# is_sponsored
# has_coupon
# buy_box_availability
# delivery_date
# sustainability_tags
# product_image_url
# product_page_url
# data_collected_at
# product_category

# %%
for column in cat_df:
  mode_value= print(cat_df[column].mode().values[0])
  cat_df[column]=cat_df[column].fillna(mode_vlue)
# Out:
# Duracell Coppertop 9V Battery, 6 Count (Pack of 1), 9 Volt Battery with Long-lasting Power, All-Purpose Alkaline 9V Battery for Household and Office Devices
# No Badge
# Organic
# No Coupon
# Add to cart
# 2025-09-04
# Small Business
# https://m.media-amazon.com/images/I/51Xr76m2WLL._AC_UL320_.jpg
# ...

# %%
for column in cat_df:
    mode_vlue= cat_df[column].mode().values[0]
    cat_df[column]=cat_df[column].fillna(mode_vlue)

# %%
cat_df.isnull().sum()
# Out:
# product_title           0
# is_best_seller          0
# is_sponsored            0
# has_coupon              0
# buy_box_availability    0
# delivery_date           0
# sustainability_tags     0
# product_image_url       0
# product_page_url        0
# data_collected_at       0
# product_category        0
# dtype: int64

# %%
df=pd.concat([num_df,cat_df],axis=1)
df.head()
# Out:
#    product_rating  total_reviews  purchased_last_month  discounted_price  \
# 0             4.6          375.0                 300.0             89.68
# 1             4.3         2457.0                6000.0              9.99
# 2             4.6         3044.0                2000.0            314.00
# 3             4.6        35882.0               10000.0            162.24
# 4             4.8        28988.0               10000.0             72.74
#
#    original_price  discount_percentage  \
# 0          159.00                43.60
# 1           15.99                37.52
# 2          349.00                10.03
# 3          162.24                 0.00
# 4           72.74                 0.00
#
#                                        product_title is_best_seller  \
# 0  BOYA BOYALINK 2 Wireless Lavalier Microphone f...       No Badge
# 1  LISEN USB C to Lightning Cable, 240W 4 in 1 Ch...       No Badge
# 2  DJI Mic 2 (2 TX + 1 RX + Charging Case), Wirel...       No Badge
# ...

# %%
df.isnull().sum()
# Out:
# product_rating          0
# total_reviews           0
# purchased_last_month    0
# discounted_price        0
# original_price          0
# discount_percentage     0
# product_title           0
# is_best_seller          0
# is_sponsored            0
# has_coupon              0
# buy_box_availability    0
# delivery_date           0
# sustainability_tags     0
# product_image_url       0
# product_page_url        0
# data_collected_at       0
# product_category        0
# dtype: int64

# %%
df['total_reviews']=df['total_reviews'].astype(int)

# %%
df['purchased_last_month']=df['purchased_last_month'].astype(int)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 42675 entries, 0 to 42674
# Data columns (total 17 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   product_rating        42675 non-null  float64
#  1   total_reviews         42675 non-null  int64
#  2   purchased_last_month  42675 non-null  int64
#  3   discounted_price      42675 non-null  float64
#  4   original_price        42675 non-null  float64
#  5   discount_percentage   42675 non-null  float64
#  6   product_title         42675 non-null  str
#  7   is_best_seller        42675 non-null  str
#  8   is_sponsored          42675 non-null  str
#  9   has_coupon            42675 non-null  str
#  10  buy_box_availability  42675 non-null  str
#  11  delivery_date         42675 non-null  str
#  12  sustainability_tags   42675 non-null  str
#  13  product_image_url     42675 non-null  str
#  14  product_page_url      42675 non-null  str
# ...

# %%
df['delivery_date']=pd.to_datetime(df['delivery_date'],errors='coerce')

# %%
df['data_collected_at']=pd.to_datetime(df['data_collected_at'],errors='coerce')

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 42675 entries, 0 to 42674
# Data columns (total 17 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   product_rating        42675 non-null  float64
#  1   total_reviews         42675 non-null  int64
#  2   purchased_last_month  42675 non-null  int64
#  3   discounted_price      42675 non-null  float64
#  4   original_price        42675 non-null  float64
#  5   discount_percentage   42675 non-null  float64
#  6   product_title         42675 non-null  str
#  7   is_best_seller        42675 non-null  str
#  8   is_sponsored          42675 non-null  str
#  9   has_coupon            42675 non-null  str
#  10  buy_box_availability  42675 non-null  str
#  11  delivery_date         30692 non-null  datetime64[us]
#  12  sustainability_tags   42675 non-null  str
#  13  product_image_url     42675 non-null  str
#  14  product_page_url      42675 non-null  str
# ...

# %%
Truedf.drop(['sustainability_tags'],axis=1,inplace=)
# Out:
#   Cell In[334], line 1
#     Truedf.drop(['sustainability_tags'],axis=1,inplace=)
#                                                ^
# SyntaxError: expected argument value expression

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 42675 entries, 0 to 42674
# Data columns (total 19 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   product_rating        42675 non-null  float64
#  1   total_reviews         42675 non-null  int64
#  2   purchased_last_month  42675 non-null  int64
#  3   discounted_price      42675 non-null  float64
#  4   original_price        42675 non-null  float64
#  5   discount_percentage   42675 non-null  float64
#  6   product_title         42675 non-null  str
#  7   is_best_seller        42675 non-null  str
#  8   is_sponsored          42675 non-null  str
#  9   has_coupon            42675 non-null  str
#  10  buy_box_availability  42675 non-null  str
#  11  delivery_date         30692 non-null  datetime64[us]
#  12  sustainability_tags   42675 non-null  str
#  13  product_image_url     42675 non-null  str
#  14  product_page_url      42675 non-null  str
# ...

# %% [markdown]
# *****FEATURE ENGINEERING

# %%
df['discounted_mount']=df['original_price']-df['discounted_price']

# %%
df['estimated_revenue']=df['discounted_price']*df['purchased_last_month']

# %%
df['days_difference']=df['delivery_date']-df['data_collected_at']

# %%
df['percentage_band']=pd.cut(df['discounted_price'],bins=[0,50,100,150,200],labels=['0-50','51-100','101-150','151-200'])

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 42675 entries, 0 to 42674
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   product_rating        42675 non-null  float64
#  1   total_reviews         42675 non-null  int64
#  2   purchased_last_month  42675 non-null  int64
#  3   discounted_price      42675 non-null  float64
#  4   original_price        42675 non-null  float64
#  5   discount_percentage   42675 non-null  float64
#  6   product_title         42675 non-null  str
#  7   is_best_seller        42675 non-null  str
#  8   is_sponsored          42675 non-null  str
#  9   has_coupon            42675 non-null  str
#  10  buy_box_availability  42675 non-null  str
#  11  delivery_date         30692 non-null  datetime64[us]
#  12  sustainability_tags   42675 non-null  str
#  13  product_image_url     42675 non-null  str
#  14  product_page_url      42675 non-null  str
# ...

# %% [markdown]
# ***UNIVARIATE ANALYSIS

# %% [markdown]
# ***categorical

# %%
df['percentage_band'].value_counts()
# Out:
# percentage_band
# 0-50       15670
# 51-100      8681
# 101-150     4400
# 151-200     2749
# Name: count, dtype: int64

# %% [markdown]
# ***numerical

# %%
df['total_reviews'].describe()
# Out:
# count     42675.000000
# mean       3021.260316
# std       12880.020115
# min           1.000000
# 25%          84.000000
# 50%         343.000000
# 75%        1825.500000
# max      865598.000000
# Name: total_reviews, dtype: float64

# %%
df.describe()
# Out:
#        product_rating  total_reviews  purchased_last_month  discounted_price  \
# count    42675.000000   42675.000000          42675.000000      42675.000000
# mean         4.401844    3021.260316           1024.291740        235.581471
# min          1.000000       1.000000             50.000000          2.160000
# 25%          4.200000      84.000000            100.000000         29.990000
# 50%          4.500000     343.000000            200.000000         84.990000
# 75%          4.600000    1825.500000            300.000000        216.660000
# max          5.000000  865598.000000         100000.000000       5449.000000
# std          0.382636   12880.020115           5505.478841        463.018884
#
#        original_price  discount_percentage               delivery_date  \
# count    42675.000000         42675.000000                       30692
# mean       249.464040             6.230801  2025-09-04 06:42:02.298970
# ...

# %% [markdown]
# ***BI VARIATE,
# CAT-CAT
# CAT-NUM
# NUM-NUM

# %% [markdown]
# CAT VS NUM
# *GROUPBY

# %%
df[['is_sponsored','purchased_last_month']].head()
# Out:
#   is_sponsored  purchased_last_month
# 0    Sponsored                   300
# 1    Sponsored                  6000
# 2    Sponsored                  2000
# 3      Organic                 10000
# 4      Organic                 10000

# %%
df.groupby('is_sponsored')['purchased_last_month'].mean()
# Out:
# is_sponsored
# Organic       430.542003
# Sponsored    4044.615604
# Name: purchased_last_month, dtype: float64

# %%
df.groupby('is_sponsored')['purchased_last_month'].sum()
# Out:
# is_sponsored
# Organic      15354850
# Sponsored    28356800
# Name: purchased_last_month, dtype: int64

# %% [markdown]
# **BAR CHAT

# %%
df.groupby('is_sponsored')['purchased_last_month'].mean().plot(kind='bar')
# Out:
# <Axes: xlabel='is_sponsored'>

# %%
df[['product_category','purchased_last_month']].head()
# Out:
#   product_category  purchased_last_month
# 0           Phones                   300
# 1          Laptops                  6000
# 2          Laptops                  2000
# 3           Phones                 10000
# 4           Phones                 10000

# %%
df.groupby('product_category')['purchased_last_month'].mean()
# Out:
# product_category
# Cameras                 285.803644
# Chargers & Cables       479.841789
# Gaming                  188.009889
# Headphones              231.043129
# Laptops                 440.383067
# Networking              300.794393
# Other Electronics       467.367219
# Phones                  591.337803
# Power & Batteries      9096.367744
# Printers & Scanners     331.185861
# Smart Home              282.150538
# Speakers                224.498141
# Storage                 385.306748
# TV & Display            367.737643
# Wearables              1733.149780
# Name: purchased_last_month, dtype: float64

# %%
df.groupby('product_category')['purchased_last_month'].mean().plot(kind='bar')
# Out:
# <Axes: xlabel='product_category'>

# %% [markdown]
# ***CAT VS CAT
#
# *CROSSTAB

# %%
df.columns
# Out:
# Index(['product_rating', 'total_reviews', 'purchased_last_month',
#        'discounted_price', 'original_price', 'discount_percentage',
#        'product_title', 'is_best_seller', 'is_sponsored', 'has_coupon',
#        'buy_box_availability', 'delivery_date', 'sustainability_tags',
#        'product_image_url', 'product_page_url', 'data_collected_at',
#        'product_category', 'days_difference', 'percentage_band',
#        'discounted_mount', 'estimated_revenue'],
#       dtype='str')

# %%
df[['product_category','is_sponsored']].head()
# Out:
#   product_category is_sponsored
# 0           Phones    Sponsored
# 1          Laptops    Sponsored
# 2          Laptops    Sponsored
# 3           Phones      Organic
# 4           Phones      Organic

# %%
pd.crosstab(index=df['product_category'], columns=df['is_sponsored'])
# Out:
# is_sponsored         Organic  Sponsored
# product_category
# Cameras                 3109        568
# Chargers & Cables       1573        260
# Gaming                   797         12
# Headphones               798        199
# Laptops                 8061        632
# Networking               837        233
# Other Electronics       8568        187
# Phones                  5190       1373
# Power & Batteries       1339       1538
# Printers & Scanners      877          0
# Smart Home               456          9
# Speakers                1119        226
# Storage                 1097        533
# TV & Display            1407       1223
# Wearables                436         18

# %%
pd.crosstab(index=df['is_sponsored'], columns=df['product_category'])
# Out:
# product_category  Cameras  Chargers & Cables  Gaming  Headphones  Laptops  \
# is_sponsored
# Organic              3109               1573     797         798     8061
# Sponsored             568                260      12         199      632
#
# product_category  Networking  Other Electronics  Phones  Power & Batteries  \
# is_sponsored
# Organic                  837               8568    5190               1339
# Sponsored                233                187    1373               1538
#
# product_category  Printers & Scanners  Smart Home  Speakers  Storage  \
# is_sponsored
# Organic                           877         456      1119     1097
# Sponsored                           0           9       226      533
#
# product_category  TV & Display  Wearables
# is_sponsored
# Organic                   1407        436
# Sponsored                 1223         18

# %%
pd.crosstab(index=df['is_sponsored'], columns=df['product_category']).mean().plot(kind='bar')
# Out:
# <Axes: xlabel='product_category'>

# %% [markdown]
# ****NUM VS NUM
#
#
# *CORRELATION*

# %%
df.columns
# Out:
# Index(['product_rating', 'total_reviews', 'purchased_last_month',
#        'discounted_price', 'original_price', 'discount_percentage',
#        'product_title', 'is_best_seller', 'is_sponsored', 'has_coupon',
#        'buy_box_availability', 'delivery_date', 'sustainability_tags',
#        'product_image_url', 'product_page_url', 'data_collected_at',
#        'product_category', 'days_difference', 'percentage_band',
#        'discounted_mount', 'estimated_revenue'],
#       dtype='str')

# %% [markdown]
#     ***NEGATIVE CORRELATION

# %%
df[['discounted_price','purchased_last_month']].corr()
# Out:
#                       discounted_price  purchased_last_month
# discounted_price              1.000000             -0.070198
# purchased_last_month         -0.070198              1.000000

# %% [markdown]
# ****POSITIVE CORRELTION

# %%
df[['original_price','discounted_price']].corr()
# Out:
#                   original_price  discounted_price
# original_price          1.000000          0.974735
# discounted_price        0.974735          1.000000

# %% [markdown]
# *****MULTI VAARIAE
# *JJ

# %%
df.columns
# Out:
# Index(['product_rating', 'total_reviews', 'purchased_last_month',
#        'discounted_price', 'original_price', 'discount_percentage',
#        'product_title', 'is_best_seller', 'is_sponsored', 'has_coupon',
#        'buy_box_availability', 'delivery_date', 'sustainability_tags',
#        'product_image_url', 'product_page_url', 'data_collected_at',
#        'product_category', 'days_difference', 'percentage_band',
#        'discounted_mount', 'estimated_revenue'],
#       dtype='str')

# %%
df[['product_category','product_rating','purchased_last_month']].head(2)
# Out:
#   product_category  product_rating  purchased_last_month
# 0           Phones             4.6                   300
# 1          Laptops             4.3                  6000

# %%
df['is_best_seller'].value_counts()
# Out:
# is_best_seller
# No Badge             40814
# Amazon's               744
# Limited time deal      409
# Best Seller            275
# Save 30%               125
# Ends in                 97
# Save 10%                61
# Save 18%                57
# Save 17%                51
# Save 12%                26
# Save 9%                 14
# Save 77%                 2
# Name: count, dtype: int64

# %% [markdown]
# *PIVOT.
#
#
#
#
# INDX-CAT
# COLUMN-CAT
# VALUES-NUM

# %%
pd.pivot_table(df,index=['product_category'], columns=['is_sponsored'], values=['purchased_last_month'])
# Out:
#                     purchased_last_month
# is_sponsored                     Organic     Sponsored
# product_category
# Cameras                       280.797684    313.204225
# Chargers & Cables             528.258106    186.923077
# Gaming                        187.829360    200.000000
# Headphones                    258.270677    121.859296
# Laptops                       401.327379    938.528481
# Networking                    323.476703    219.313305
# Other Electronics             466.211485    520.320856
# Phones                        422.880539   1228.113620
# Power & Batteries            1167.176998  15999.609883
# Printers & Scanners           331.185861           NaN
# Smart Home                    284.210526    177.777778
# Speakers                      229.624665    199.115044
# Storage                       421.103008    311.632270
# TV & Display                  455.828003    266.394113
# Wearables                     589.105505  29444.444444

# %%
pd.pivot_table(df,index=['product_category'], columns=['is_sponsored'], values=['purchased_last_month'],aggfunc='sum')
# Out:
#                     purchased_last_month
# is_sponsored                     Organic   Sponsored
# product_category
# Cameras                         873000.0    177900.0
# Chargers & Cables               830950.0     48600.0
# Gaming                          149700.0      2400.0
# Headphones                      206100.0     24250.0
# Laptops                        3235100.0    593150.0
# Networking                      270750.0     51100.0
# Other Electronics              3994500.0     97300.0
# Phones                         2194750.0   1686200.0
# Power & Batteries              1562850.0  24607400.0
# Printers & Scanners             290450.0         NaN
# Smart Home                      129600.0      1600.0
# Speakers                        256950.0     45000.0
# Storage                         461950.0    166100.0
# TV & Display                    641350.0    325800.0
# Wearables                       256850.0    530000.0

# %%
pd.pivot_table(df,index=['product_category'], columns=['is_sponsored'], values=['purchased_last_month'],aggfunc='mean')
# Out:
#                     purchased_last_month
# is_sponsored                     Organic     Sponsored
# product_category
# Cameras                       280.797684    313.204225
# Chargers & Cables             528.258106    186.923077
# Gaming                        187.829360    200.000000
# Headphones                    258.270677    121.859296
# Laptops                       401.327379    938.528481
# Networking                    323.476703    219.313305
# Other Electronics             466.211485    520.320856
# Phones                        422.880539   1228.113620
# Power & Batteries            1167.176998  15999.609883
# Printers & Scanners           331.185861           NaN
# Smart Home                    284.210526    177.777778
# Speakers                      229.624665    199.115044
# Storage                       421.103008    311.632270
# TV & Display                  455.828003    266.394113
# Wearables                     589.105505  29444.444444

# %%
pd.pivot_table(df,index=['product_category'], columns=['is_sponsored'], values=['purchased_last_month'],aggfunc='median')
# Out:
#                     purchased_last_month
# is_sponsored                     Organic Sponsored
# product_category
# Cameras                            200.0     200.0
# Chargers & Cables                  200.0     200.0
# Gaming                             100.0     200.0
# Headphones                         100.0      50.0
# Laptops                            200.0     200.0
# Networking                         200.0     200.0
# Other Electronics                  200.0     200.0
# Phones                             200.0    1000.0
# Power & Batteries                  200.0   20000.0
# Printers & Scanners                100.0       NaN
# Smart Home                         200.0     200.0
# Speakers                           200.0     200.0
# Storage                            200.0     200.0
# TV & Display                       200.0     200.0
# Wearables                          700.0   30000.0

# %% [markdown]
# **OBSERVATION
